# %% [markdown]
# <a href="https://colab.research.google.com/github/shreya-s-devadiga/git-lab/blob/main/graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x =[10,20,30,40,50]
y = [1,2,3,4,5]
plt.plot(x, y)
plt.title("line graph")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()
